# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Telco-Customer-Churn.csv')

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5479  8990-ZXLSU  Female              0      No         No       9
# 6313  0754-UKWQP    Male              0      No         No       2
# 5046  7252-NTGSS  Female              0      No         No       1
# 1424  7560-QRBXH  Female              0      No        Yes      48
# 5973  2324-EFHVG    Male              0      No         No      64
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5479          Yes            No     Fiber optic                   No  ...
# 6313          Yes            No     Fiber optic                   No  ...
# 5046          Yes            No             DSL                   No  ...
# 1424          Yes            No              No  No internet service  ...
# 5973          Yes           Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.drop(['customerID','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','PaperlessBilling','PaymentMethod'], axis=1, inplace=True)

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure TechSupport  \
# 2951    Male              0     Yes         No      20         Yes
# 107   Female              0      No         No      32          No
# 6977    Male              0      No         No      24          No
# 4804  Female              0      No         No      61         Yes
# 126   Female              1      No         No      27          No
#
#      StreamingTV StreamingMovies        Contract  MonthlyCharges TotalCharges  \
# 2951          No             Yes        One year           64.15      1274.45
# 107           No              No        One year           30.15       927.65
# 6977          No              No  Month-to-month           49.70      1218.25
# 4804         Yes             Yes        One year          118.60       7365.7
# 126           No              No  Month-to-month           78.05       2135.5
#
#      Churn
# 2951    No
# 107     No
# 6977    No
# 4804    No
# 126    Yes

# %%
df.isnull().sum()
# Out:
# gender             0
# SeniorCitizen      0
# Partner            0
# Dependents         0
# tenure             0
# TechSupport        0
# StreamingTV        0
# StreamingMovies    0
# Contract           0
# MonthlyCharges     0
# TotalCharges       0
# Churn              0
# dtype: int64

# %%
#Scatter plot for (Numerical - Numerical Values)
sns.scatterplot(data=df, x='MonthlyCharges', y='tenure', hue='gender')
#sns.scatterplot(data = df, x = 'TotalCharges', y = 'tenure', hue='gender', style='smoker',size='size')
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='tenure'>

# %%
#Bar Plot - (Numerical - Categorical)
sns.barplot(data = df, x = 'MonthlyCharges', y = 'tenure', hue='gender') #that line is confidence interval
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='tenure'>
# c:\Users\Sanjog Bhalla\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# c:\Users\Sanjog Bhalla\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.countplot(x ='Churn', data = df)
#df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x ='gender', data = df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
#we will make pieplot
df["gender"].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#we will make pieplot
df["Churn"].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#Contract
df["Contract"].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x ='SeniorCitizen', data = df)
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>
